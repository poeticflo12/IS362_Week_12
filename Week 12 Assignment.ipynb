# %% [markdown]
# # <center><font color='blue'>IS362 Assignment 12 Fall 2020</center><font>

# %% [markdown]
# ![My_Text](https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSZtgSr9JkT6mwn474na4hRPHouehtMwM94lQ&usqp=CAU)

# %% [markdown]
# #### The New York Times web site provides a rich set of APIs, as described here:  http://developer.nytimes.com/docs
#
# #### You'll need to start by signing up for an API key.
#
# #### Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the data, and transform it into a pandas DataFrame.

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json, requests

# %% [markdown]
# ##### I have selected the Movie Reviews API
# ##### My Movie Reviews API Key is:  Up2JZP7rkAEV4QspK0Pq0l1Es8eXTI5P

# %%
# my personal api key
api_key = 'Up2JZP7rkAEV4QspK0Pq0l1Es8eXTI5P'
# base url to make api call
url = 'https://api.nytimes.com/svc/movies/v2/reviews/search.json?'
# combine api call url and api key
myrequest = url + '&api-key=' + api_key
# load and display data
reviewmovies = json.loads(requests.get(myrequest).text) 
reviewmovies
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2020 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'display_title': 'Come Away',
#    'mpaa_rating': 'PG',
#    'critics_pick': 0,
#    'byline': 'Natalia Winkelman',
#    'headline': '‘Come Away’ Review: Escaping Grief Through Fantasy',
#    'summary_short': 'David Oyelowo and Angelina Jolie play grieving parents in a dreary melodrama that imagines Peter Pan and Alice (of Wonderland) as siblings.',
#    'publication_date': '2020-11-13',
#    'opening_date': '2020-11-13',
#    'date_updated': '2020-11-13 18:42:30',
#    'link': {'type': 'article',
#     'url': 'http://www.nytimes.com/2020/11/13/movies/come-away-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Come Away'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
# ...

# %% [markdown]
# #### I need to transform data into a readable format.

# %%
transform = json_normalize(reviewmovies['results'])
transform
# Out:
# <ipython-input-5-3e91dfae8399>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   transform = json_normalize(reviewmovies['results'])
#                             display_title mpaa_rating  critics_pick  \
# 0                               Come Away          PG             0
# 1      Jingle Jangle: A Christmas Journey          PG             1
# 2   Fireball: Visitors from Darker Worlds                         1
# 3                                Ammonite           R             1
# 4                               The Climb           R             0
# 5                               Dreamland           R             0
# 6                          The Life Ahead       PG-13             0
# 7                             Wolfwalkers          PG             0
# 8                                 Monsoon                         0
# 9                                 Make Up                         0
# ...

# %% [markdown]
# #### Panda Fame

# %%
# Transforming data into panda DataFrame, while trying to display the columns below.  
# (display_title, mpaa_rating, opening_date, byline)
df = transform[['display_title', 'byline','publication_date', 'critics_pick']]
df
# Out:
#                             display_title               byline  \
# 0                               Come Away    Natalia Winkelman
# 1      Jingle Jangle: A Christmas Journey        Lovia Gyarkye
# 2   Fireball: Visitors from Darker Worlds          Glenn Kenny
# 3                                Ammonite  Jeannette Catsoulis
# 4                               The Climb           A.O. Scott
# 5                               Dreamland       Manohla Dargis
# 6                          The Life Ahead          Glenn Kenny
# 7                             Wolfwalkers          Glenn Kenny
# 8                                 Monsoon       Ben Kenigsberg
# 9                                 Make Up           Teo Bugbee
# 10                                 Freaky  Jeannette Catsoulis
# 11                             I Am Greta       Nicolas Rapold
# 12                                 Fatman  Jeannette Catsoulis
# 13                             Coded Bias        Devika Girish
# ...
